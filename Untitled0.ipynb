# %% [markdown]
# <a href="https://colab.research.google.com/github/Ujjwal-21/Bank/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# !pip install pmdarima
import os
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from pmdarima.arima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

# %%
bank_data = pd.read_csv('/content/drive/MyDrive/STRBI_Table_No._01_Liabilities_and_Assets_of_Scheduled_Commercial_Banks (2).csv')

# %%
bank_data.head()
# Out:
#    Year                  Banks 1.     Cash in hand\n  \
# 0  2021         BANK OF BARODA                4178.2
# 1   NaN          BANK OF INDIA               3295.51
# 2   NaN    BANK OF MAHARASHTRA               1006.86
# 3   NaN            CANARA BANK               4400.38
# 4   NaN  CENTRAL BANK OF INDIA               1475.16
#
#   2.     Balances with RBI\n 3.     Balances with banks in India\n  \
# 0                   34662.83                                4343.5
# 1                   57402.06                                 102.1
# 2                   11875.63                                 41.34
# 3                   38711.24                                 60.87
# 4                   30712.68                                 52.12
#
#   4.     Money at call and short notice\n  \
# 0                                 17306.2
# 1                                 15554.8
# 2                                       -
# 3                                82698.16
# ...

# %%
dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m-%d')
stock_data = pd.read_csv('/content/drive/MyDrive/STRBI_Table_No._01_Liabilities_and_Assets_of_Scheduled_Commercial_Banks (2).csv')
stock_data
# Out:
#                       Year                             Banks  \
# 0                     2021                    BANK OF BARODA
# 1                      NaN                     BANK OF INDIA
# 2                      NaN               BANK OF MAHARASHTRA
# 3                      NaN                       CANARA BANK
# 4                      NaN             CENTRAL BANK OF INDIA
# ...                    ...                               ...
# 3175                   NaN  INDIA POST PAYMENTS BANK LIMITED
# 3176                   NaN                    PAYMENTS BANKS
# 3177                   NaN    ALL SCHEDULED COMMERCIAL BANKS
# 3178                   NaN                               NaN
# 3179  See Notes on Tables.                               NaN
#
#      1.     Cash in hand\n 2.     Balances with RBI\n  \
# 0                   4178.2                   34662.83
# 1                  3295.51                   57402.06
# 2                  1006.86                   11875.63
# ...

# %%
selected_features= ['Year','Cash in hand','Balances with RBI',' Balances with banks in India','Money at call and short notice','Balances with banks outside India','Investments','Investments in India','Government securities','Premises','Fixed assets under construction','Other Fixed assets','Other Assets','Inter-office adjustments (net)','Interest accrued ','Tax paid',' Stationery and Stamps','Others','Total Assets']
print(selected_features)
# Out:
# ['Year', 'Cash in hand', 'Balances with RBI', ' Balances with banks in India', 'Money at call and short notice', 'Balances with banks outside India', 'Investments', 'Investments in India', 'Government securities', 'Premises', 'Fixed assets under construction', 'Other Fixed assets', 'Other Assets', 'Inter-office adjustments (net)', 'Interest accrued ', 'Tax paid', ' Stationery and Stamps', 'Others', 'Total Assets']

# %%
for feature in selected_features:
  stock_data[feature]=stock_data[feature].fillna('')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cash in hand'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#plot close price
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Year')
plt.ylabel('Total Assets')
plt.plot(stock_data['Total Assets'])
plt.title('ARCH CAPITAL GROUP closing price')
plt.show()

# %%
#Distribution of the dataset
df_close = stock_data['Total Assets']
df_close.plot(kind='kde')

# %%
#Test for staionarity
def test_stationarity(timeseries):
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()
    #Plot rolling statistics:
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.show(block=False)
    print("Results of dickey fuller test")
    adft = adfuller(timeseries,autolag='AIC')
    # output for dft will give us without defining what the values are.
    #hence we manually write what values does it explains using a for loop
    output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key] =  values
    print(output)
test_stationarity(df_close)
# Out:
# Results of dickey fuller test
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-37-13897a1f0ee2> in <module>()
#      19         output['critical value (%s)'%key] =  values
#      20     print(output)
# ---> 21 test_stationarity(df_close)
#
# <ipython-input-37-13897a1f0ee2> in test_stationarity(timeseries)
#      12     plt.show(block=False)
#      13     print("Results of dickey fuller test")
# ---> 14     adft = adfuller(timeseries,autolag='AIC')
#      15     # output for dft will give us without defining what the values are.
#      16     #hence we manually write what values does it explains using a for loop
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     320         if not regresults:
#     321             icbest, bestlag = _autolag(
# ...

# %%
#if not stationary then eliminate trend
#Eliminate trend
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
df_log = np.log(df_close)
moving_avg = df_log.rolling(12).mean()
std_dev = df_log.rolling(12).std()
plt.legend(loc='best')
plt.title('Moving Average')
plt.plot(std_dev, color ="black", label = "Standard Deviation")
plt.plot(moving_avg, color="red", label = "Mean")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#split data into train and training set
train_data, test_data = df_log[3:int(len(df_log)*0.9)], df_log[int(len(df_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(df_log, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend()

# %%
model_autoARIMA = auto_arima(bank_data, start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
print(model_autoARIMA.summary())
model_autoARIMA.plot_diagnostics(figsize=(15,8))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-83a28f31fbcb> in <module>()
#      10                       error_action='ignore',
#      11                       suppress_warnings=True,
# ---> 12                       stepwise=True)
#      13 print(model_autoARIMA.summary())
#      14 model_autoARIMA.plot_diagnostics(figsize=(15,8))
#
# /usr/local/lib/python3.7/dist-packages/pmdarima/arima/auto.py in auto_arima(y, X, start_p, d, start_q, max_p, max_d, max_q, start_P, D, start_Q, max_P, max_D, max_Q, max_order, m, seasonal, stationary, information_criterion, alpha, test, seasonal_test, stepwise, n_jobs, start_params, trend, method, maxiter, offset_test_args, seasonal_test_args, suppress_warnings, error_action, trace, random, random_state, n_fits, return_valid_fits, out_of_sample_size, scoring, scoring_args, with_intercept, sarimax_kwargs, **fit_args)
# ...

# %%
#Modeling
# Build Model
model = ARIMA(bank_data, order=(1,1,2))  
fitted = model.fit(disp=-1)  
print(fitted.summary())
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-49-c3902cbb208b> in <module>()
#       1 #Modeling
#       2 # Build Model
# ----> 3 model = ARIMA(bank_data, order=(1,1,2))
#       4 fitted = model.fit(disp=-1)
#       5 print(fitted.summary())
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/arima_model.py in __init__(self, *args, **kwargs)
#      43
#      44     def __init__(self, *args, **kwargs):
# ---> 45         super().__init__(*args, **kwargs)
#      46
#      47
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/arima_model.py in __init__(self, *args, **kwargs)
#      27
#      28     def __init__(self, *args, **kwargs):
# ---> 29         raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#      30
#      31
#
# NotImplementedError:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# ...

# %%
# Forecast
fc, se, conf = fitted.forecast(321, alpha=0.05)  # 95% conf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-a2ec11e98838> in <module>()
#       1 # Forecast
# ----> 2 fc, se, conf = fitted.forecast(321, alpha=0.05)  # 95% conf
#
# NameError: name 'fitted' is not defined

# %%
# Make as pandas series
fc_series = pd.Series(fc, index=bank_data.index)
lower_series = pd.Series(conf[:, 0], index=bank_data.index)
upper_series = pd.Series(conf[:, 1], index=bank_data.index)
# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training data')
plt.plot(test_data, color = 'blue', label='Actual Stock Price')
plt.plot(fc_series, color = 'orange',label='Predicted Stock Price')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.10)
plt.title('ARCH CAPITAL GROUP Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('ARCH CAPITAL GROUP Stock Price')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-d5c18c3a1cc4> in <module>()
#       1 # Make as pandas series
# ----> 2 fc_series = pd.Series(fc, index=bank_data.index)
#       3 lower_series = pd.Series(conf[:, 0], index=bank_data.index)
#       4 upper_series = pd.Series(conf[:, 1], index=bank_data.index)
#       5 # Plot
#
# NameError: name 'fc' is not defined

# %%
# report performance
mse = mean_squared_error(test_data, fc)
print('MSE: '+str(mse))
mae = mean_absolute_error(test_data, fc)
print('MAE: '+str(mae))
rmse = math.sqrt(mean_squared_error(test_data, fc))
print('RMSE: '+str(rmse))
mape = np.mean(np.abs(fc - test_data)/np.abs(test_data))
print('MAPE: '+str(mape))
